# %% [markdown]
# # Putting together the plan for the next datavis course
#
# - Have a much briefer intro talk with more figures
# - A little bit more discussion of the kind of benefits of making figures with Python as opposed to a graphics program
# - Use RISE for making presentations...
#
# Can reintroduce concepts in each session.
#
# I also think we should probably stick to a single example dataset for all the plots... Let people fully dive in to all the options.
#
# ## Course content
#
# Needs to be updated slightly - general content can stay the same but overall setup and organisation should change.
#
# Keep it all in colab, but provide some example notebooks
#
# ### First session: layout basics
#
# - Quick intro to colab, show how to load in example notebooks
#
# - Making basic line and scatter plots
# - Setting colours, line thickness, opacity, marker style/line style
# - Setting location of legend, suptitle, multi-panel plots
#
# ### Heatmaps and colourmaps
#
# - Different types of heatmap and use of colour scales in general:
#     - Ordered vs. unordered values: does your colour scale agree? - maybe in a brief talk?
#     - Perceptively uniform colourmaps, cyclic ones, being aware of the different types and the effects they have
# - Basic imshow plot for heatmap and adding a colourbar, organising layout around this
# - Statistical heatmap, correlation plot
#
# ### Exploratory data visualisation
#
# ### External libraries: utilising seaborn for layouts?
#
# ### Statistical plots
#
# ---
#
# jupyter nbconvert sample.ipynb --to slides --no-prompt --TagRemovePreprocessor.remove_input_tags={\"to_remove\"} --post serve
#
# jupyter nbconvert sample.ipynb --to slides --no-prompt --post serve
#
# jupyter nbconvert presentation-intro.ipynb --to slides --no-prompt --no-input --post serve

# %%
import matplotlib.pyplot as plt
import bokeh
import numpy as np

# %%
x = np.arange(0, 1000, 25)

# %%
y = np.sin(x) + np.cos(x/2)

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)
