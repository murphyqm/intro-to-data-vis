# %%
# %%html
# <style type="text/css">

# .reveal p {
# font-size:18pt;
# }
# </style>

# jupyter nbconvert presentation-intro.ipynb --to slides --no-prompt --no-input --post serve
# Out:
# <style type="text/css">
#
# .reveal p {
# font-size:18pt;
# }
# </style>

# %% [markdown]
# # An introduction to Data Visualisation
#
# ## With Python

# %% [markdown]
# ## Good Data Visualisation
#
# - ### Objective and unbiased representation of the data
#
# - ### Should deliver meaningful results and illustrate something useful about the data
#
# - ### All information required to understand it should be available in the legend and/or caption (but may require domain specific knowledge)

# %% [markdown]
# - ### Can also be used to explore your data - figures and plots for you and your collaborators, not for publication!

# %% [markdown]
# ## What's needed for **Good Data Visualisation**?

# %% [markdown]
# - ### Evidence-based best practises for objective data representation

# %% [markdown]
# - ### Technical skills in tools to build graphics

# %% [markdown]
# - ### Domain-specific knowlege of underlying dataset

# %% [markdown]
# - ### Creativity and subjective taste

# %% [markdown]
# ## Who is your intended audience?

# %% [markdown]
# - ### General public, non-research audiences
#     - Sci-art
#     - Infographics

# %% [markdown]
# - ### Non-domain specific, but technical audiences

# %% [markdown]
# - ### Domain specific research audiences

# %% [markdown]
# - ### Your collaborators

# %% [markdown]
# - ### You!

# %% [markdown]
# ![encoding](encoding.jpg)

# %% [markdown]
# <style>
# td, th {
#    border: none!important;
# }
# </style>
#
# |  |  |
# |--|--|
# | ![encoding](encoding.jpg) | Encoding your data using symbols |

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dots = sns.load_dataset("dots")
dots = dots.rename(columns={"align":"Align", "choice":"Choice", "time":"Time", "coherence": "Coherence", "firing_rate": "Firing Rate"})

dots
# Out:
#     Align Choice  Time  Coherence  Firing Rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(
    data=dots,
    x="Time", y="Firing Rate",
    hue="Coherence", size="Choice", col="Align",
    kind="line", size_order=["T1", "T2"], palette=palette,
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)

plt.show()

# %%
with sns.plotting_context("talk"):
    # Plot the lines on two facets
    sns.relplot(
        data=dots,
        x="Time", y="Firing Rate",
        hue="Coherence", size="Choice", col="Align",
        kind="line", size_order=["T1", "T2"], palette=palette,
        height=5, aspect=.75, facet_kws=dict(sharex=False),
    )

    plt.show()

print("With context set to 'talk'")
# Out:
# With context set to 'talk'

# %%
with sns.plotting_context("paper"):
    # Plot the lines on two facets
    sns.relplot(
        data=dots,
        x="Time", y="Firing Rate",
        hue="Coherence", size="Choice", col="Align",
        kind="line", size_order=["T1", "T2"], palette=palette,
        height=5, aspect=.75, facet_kws=dict(sharex=False),
    )

    plt.show()

print("With context set to 'paper'")
# Out:
# With context set to 'paper'

# %% [markdown]
# <div style='position: relative; padding-bottom: 56.25%; padding-top: 35px; height: 0; overflow: hidden;'><iframe sandbox='allow-scripts allow-same-origin allow-presentation' allowfullscreen='true' allowtransparency='true' frameborder='0' height='315' src='https://www.mentimeter.com/app/presentation/aljxy8e5vpxbdy28aqrhpxciqczr64cq/embed' style='position: absolute; top: 0; left: 0; width: 100%; height: 100%;' width='420'></iframe></div>
